# %% [markdown]
# <a href="https://colab.research.google.com/github/truptisude/HR_Analytics_PowerBi_Dashboard/blob/main/From_Ratings_to_Reality_A_Deep_Dive_into_User_Feedback_on_Blinkit%2C_Zepto%2C_and_Jiomart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Disclaimer:** This analysis is based on a sample dataset and may not fully represent the entire population of user reviews for quick commerce platforms. The insights and conclusions drawn from this analysis should be considered for informational purposes only and may not be generalizable to all users or platforms.

# %% [markdown]
# **Problem statement and objectives of the analysis.**

# %% [markdown]
# # **Quick commerce platforms** like Blinkit, Zepto, and Jiomart have witnessed a surge in negative reviews, indicating growing user dissatisfaction with their services. This analysis aims to identify the key pain points driving these negative sentiments by examining reviews and ratings across these platforms. Understanding these pain points is crucial for quick commerce companies to enhance user experience, foster customer loyalty, and ultimately, establish a sustainable competitive advantage.

# %% [markdown]
# Import required libraries for data analysis, visualization, and natural language processing.

# %%
import kagglehub
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.metrics import ConfusionMatrix
from sklearn.metrics import confusion_matrix
from wordcloud import WordCloud

# %% [markdown]
# Download and display the path to the downloaded dataset.

# %%
# Download latest version
path = kagglehub.dataset_download("mannacharya/blinkit-vs-zepto-vs-instamart-reviews")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mannacharya/blinkit-vs-zepto-vs-instamart-reviews?dataset_version_number=3...
# 100%|██████████| 561k/561k [00:00<00:00, 77.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mannacharya/blinkit-vs-zepto-vs-instamart-reviews/versions/3

# %% [markdown]
# Read the dataset into a pandas DataFrame named df.

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/mannacharya/blinkit-vs-zepto-vs-instamart-reviews/versions/3/reviews.csv')

# %%
df.head()
# Out:
#    rating              date  \
# 0       2  30 December 2024
# 1       1   4 November 2024
# 2       1   31 October 2024
# 3       5    29 August 2024
# 4       2  31 December 2024
#
#                                               review platform
# 0  I was using it for long time, but have to stop...  blinkit
# 1  Loving the fast deliveries and mostly they are...  blinkit
# 2  The customer support is very disappointing. I ...  blinkit
# 3  I've been using Blinkit for a while now, and i...  blinkit
# 4  Blinkit was my go to app and it was rare that ...  blinkit

# %% [markdown]
# Display information about the DataFrame, including column names, data types, and non-null values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rating    4620 non-null   int64
#  1   date      4620 non-null   object
#  2   review    4620 non-null   object
#  3   platform  4620 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 144.5+ KB

# %% [markdown]
# from info of df, we need to change the datatype of date to datetime

# %% [markdown]
# Convert the 'date' column to datetime objects.

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %% [markdown]
# Display updated information about the DataFrame after converting the 'date' column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rating    4620 non-null   int64
#  1   date      4620 non-null   datetime64[ns]
#  2   review    4620 non-null   object
#  3   platform  4620 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 144.5+ KB

# %% [markdown]
# Check for missing values in the DataFrame.

# %%
df.isnull().sum()
# Out:
# rating      0
# date        0
# review      0
# platform    0
# dtype: int64

# %% [markdown]
# table does not have missing values

# %% [markdown]
#  Check for duplicate rows in the DataFrame.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# table does not have duplicate values

# %% [markdown]
# Clean the 'review' column by removing non-alphabetic characters, converting to lowercase, removing stop words, and performing lemmatization.

# %%
# cleaning the review column
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_review(review):
    # Remove non-alphabetic characters and convert to lowercase
    review = review.lower()
    review = re.sub(r'[^a-zA-Z]', ' ', review)

    #remove stopwords
    words = review.split()
    words = [word for word in words if word not in stop_words]

    #lemmatization
    words = [lemmatizer.lemmatize(word) for word in words]

    #join words back into one string
    return ' '.join(words)

df['review'] = df['review'].apply(clean_review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df.head(5)
# Out:
#    rating       date                                             review  \
# 0       2 2024-12-30  using long time stop using recently got used i...
# 1       1 2024-11-04  loving fast delivery mostly great quick delive...
# 2       1 2024-10-31  customer support disappointing recently bought...
# 3       5 2024-08-29  using blinkit become go app grocery shopping a...
# 4       2 2024-12-31  blinkit go app rare disappointed today disappo...
#
#   platform
# 0  blinkit
# 1  blinkit
# 2  blinkit
# 3  blinkit
# 4  blinkit

# %% [markdown]
# # **EDA**

# %% [markdown]
# Display descriptive statistics of the numerical columns in the DataFrame.

# %%
df.describe()
# Out:
#             rating                           date
# count  4620.000000                           4620
# mean      1.827273  2024-10-12 07:19:28.831168768
# min       1.000000            2020-07-21 00:00:00
# 25%       1.000000            2024-10-25 00:00:00
# 50%       1.000000            2024-11-27 00:00:00
# 75%       2.000000            2024-12-18 00:00:00
# max       5.000000            2024-12-31 00:00:00
# std       1.461208                            NaN

# %% [markdown]
# the 75% quratal is of negative review. and mean is 1.82, standard deviation is 1.46 which is not great for delevery app rating

# %% [markdown]
# Calculate the count of ratings based on platform.

# %%
rating_count = df.groupby(['rating','platform']).size().reset_index(name='count')

# %%
rating_count
# Out:
#     rating platform  count
# 0        1  blinkit    713
# 1        1  jiomart   1216
# 2        1    zepto   1376
# 3        2  blinkit     83
# 4        2  jiomart     79
# 5        2    zepto    117
# 6        3  blinkit     78
# 7        3  jiomart     47
# 8        3    zepto     63
# 9        4  blinkit    120
# 10       4  jiomart     52
# 11       4    zepto     53
# 12       5  blinkit    386
# 13       5  jiomart    106
# 14       5    zepto    131

# %% [markdown]
# Visualize the rating distribution per platform using a countplot.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='rating', hue='platform', data=df, palette='Set2')
plt.title('Rating Distribution per Platform')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# from above chart, we can see the all plotform has received most number of negative review

# %% [markdown]
# Calculate the volume of reviews over time by month.

# %%
month_reviews = df.groupby([df['platform'],df['date'].dt.to_period('M')]).size().reset_index(name='review_count')
month_reviews.head()
# Out:
#   platform     date  review_count
# 0  blinkit  2024-07             1
# 1  blinkit  2024-08             6
# 2  blinkit  2024-09             5
# 3  blinkit  2024-10           351
# 4  blinkit  2024-11           329

# %%
#convert the period back to datetime for plotting
month_reviews['date'] = month_reviews['date'].dt.to_timestamp()
month_reviews.head()
# Out:
#   platform       date  review_count
# 0  blinkit 2024-07-01             1
# 1  blinkit 2024-08-01             6
# 2  blinkit 2024-09-01             5
# 3  blinkit 2024-10-01           351
# 4  blinkit 2024-11-01           329

# %% [markdown]
# Visualize the volume of reviews over time by month using a line plot.

# %%
#plotting seaborn
plt.figure(figsize=(12,6))
sns.lineplot(x='date', y='review_count', hue='platform', data=month_reviews, palette='Set2',marker = 'o')
plt.title('Volume of Reviews over Time by Month')
plt.xlabel('Date')
plt.ylabel('Review Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# From above line chart, we can see most number of review are started from **june 2024**. we can assume all the platform penetrate in most number devices in urban india and from negative review we assume the companies are not able to cater the public demand.
# # Example zepto has recievd most number of review and reviews are exploided after june 2024 but it has negative reviews.

# %%
#Cheking rating and review sentiment align!
#First we will convert review into sentiment score into ['positive','negative','neutral']
# vader analysis
#analysis of review column
# if reviews are bad then the vader will give negative, vice versa for positive and negative
#vadder assigns a sentiment score between -1 (most negative) and +1 (most positive), with 0 indicating neutral sentiment.

# %%
nltk.download('vader_lexicon')

def get_sentiment_score(review):
    sid = SentimentIntensityAnalyzer()
    sentiment_score = sid.polarity_scores(review)['compound']

    if(sentiment_score >= 0.05):
        return 'positive'
    elif(sentiment_score <= -0.05):
        return 'negative'
    else:
        return 'neutral'

df['sentiment_score'] = df['review'].apply(get_sentiment_score)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df.head()
# Out:
#    rating       date                                             review  \
# 0       2 2024-12-30  using long time stop using recently got used i...
# 1       1 2024-11-04  loving fast delivery mostly great quick delive...
# 2       1 2024-10-31  customer support disappointing recently bought...
# 3       5 2024-08-29  using blinkit become go app grocery shopping a...
# 4       2 2024-12-31  blinkit go app rare disappointed today disappo...
#
#   platform sentiment_score
# 0  blinkit        positive
# 1  blinkit        positive
# 2  blinkit        positive
# 3  blinkit        positive
# 4  blinkit        negative

# %%
#now we will convert rating into sentimental score - ['positive','negative','neutral']
def rating_to_sentiment(rating):
    if rating >= 4:
        return 'positive'
    elif rating <= 2:
        return 'negative'
    else:
        return 'neutral'

df['rating_sentiment'] = df['rating'].apply(rating_to_sentiment)

# %%
df.head()
# Out:
#    rating       date                                             review  \
# 0       2 2024-12-30  using long time stop using recently got used i...
# 1       1 2024-11-04  loving fast delivery mostly great quick delive...
# 2       1 2024-10-31  customer support disappointing recently bought...
# 3       5 2024-08-29  using blinkit become go app grocery shopping a...
# 4       2 2024-12-31  blinkit go app rare disappointed today disappo...
#
#   platform sentiment_score rating_sentiment
# 0  blinkit        positive         negative
# 1  blinkit        positive         negative
# 2  blinkit        positive         negative
# 3  blinkit        positive         positive
# 4  blinkit        negative         negative

# %% [markdown]
# Compare rating sentiment vs. review sentiment using a confusion matrix.

# %%
#comparing the rating sentiment vs review sentiment
conf_mat = confusion_matrix(df['rating_sentiment'], df['sentiment_score'], labels=['positive', 'negative', 'neutral'])

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Positive', 'Negative', 'Neutral'], yticklabels=['Positive', 'Negative', 'Neutral'])
plt.xlabel('Review Sentiment')
plt.ylabel('review sentiment')
plt.title('rating sentiment vs review sentiment')
plt.show()

# %% [markdown]
# From above **confusion matrix**, even though user gave positive rating but with negative review.
#
# This type rating maybe comes from Loyal User, hesitate to give low rating or its sarcasm

# %%
#alignment percentage
matches = (df['rating_sentiment'] == df['sentiment_score']).sum()
total = len(df)
accuracy = matches / total
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 65.65%

# %% [markdown]
# **Visualization**

# %% [markdown]
#  Visualize the sentiment distribution using a bar plot.

# %%
# sentimental distribution
sentiment_counts = df['sentiment_score'].value_counts()

plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='Set2')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-26-fb1b4577178d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='Set2')

# %% [markdown]
# all the platform majoritily recieved negative review.

# %%
platforms = df['platform'].unique()

for platform in platforms:
    platform_reviews = df[df['platform'] == platform]['review']

    all_platform_reviews = ' '.join(platform_reviews)

    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_platform_reviews)

    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Common Words in Reviews - {platform}')
    plt.show()

# %% [markdown]
# all the platform contains most negative reviews are about delivery, time, experince, service, refund, delivery charges, cancelled order and product.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# The delevery platform should focus on user experince, service to the user, delivery charges should cut down if necessary.
# Add new stores to residential populated areas. product quality must ensure. training to delivery boy if required.
